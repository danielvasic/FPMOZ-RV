# %% [raw]
# from skimage import io
#
# fpmoz = io.imread ("fpmoz.jpg")
# fpmoz.shape
#
# red_fpmoz = fpmoz[:,:,0]
# green_fpmoz = fpmoz[:,:,1]
# blue_fpmoz = fpmoz[:,:,2]

# %%
from skimage.exposure import histogram
red_histogram = histogram(red_fpmoz)

# %%
import matplotlib.pyplot as plt
plt.hist(x = red_histogram[0], bins=red_histogram[1])
plt.show()

# %%
from skimage import img_as_int
import numpy as np

from skimage.exposure import equalize_hist
red_eq_fpmoz = equalize_hist(red_fpmoz) 
red_eq_fpmoz *= 255
red_eq_fpmoz_int = red_eq_fpmoz.astype(np.uint8)
red_eq_histogram = histogram(red_eq_fpmoz_int)

# %%
io.imshow(red_eq_fpmoz_int)
# Out:
# /home/daniel/anaconda3/lib/python3.6/site-packages/skimage/io/_plugins/matplotlib_plugin.py:51: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   out_of_range_float = (np.issubdtype(image.dtype, np.float) and

# %%
io.imshow(red_fpmoz)
# Out:
# /home/daniel/anaconda3/lib/python3.6/site-packages/skimage/io/_plugins/matplotlib_plugin.py:51: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   out_of_range_float = (np.issubdtype(image.dtype, np.float) and

# %%
from skimage.exposure import equalize_hist
import numpy as np

red = equalize_hist(fpmoz[:,:,0])*255
red = red.astype(np.uint8)

green = equalize_hist(fpmoz[:,:,1])*255
green = green.astype(np.uint8)

blue = equalize_hist(fpmoz[:,:,2])*255
blue = blue.astype(np.uint8)

# %%
fpmoz[:,:,0] = red
fpmoz[:,:,1] = green
fpmoz[:,:,2] = blue
io.imshow(fpmoz)
# Out:
# /home/daniel/anaconda3/lib/python3.6/site-packages/skimage/io/_plugins/matplotlib_plugin.py:51: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   out_of_range_float = (np.issubdtype(image.dtype, np.float) and

# %%
from skimage.color import rgb2gray, rgb2hsv
fpmoz_hsv = rgb2hsv(fpmoz)
io.imshow(fpmoz_hsv)
# Out:
# /home/daniel/anaconda3/lib/python3.6/site-packages/skimage/io/_plugins/matplotlib_plugin.py:51: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   out_of_range_float = (np.issubdtype(image.dtype, np.float) and
