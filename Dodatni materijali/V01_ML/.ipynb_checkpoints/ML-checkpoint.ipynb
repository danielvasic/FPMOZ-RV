# %%
import pandas as pd
df = pd.read_csv("iris.data.txt", names=["SetosaLength", "SetosaWidth", "PetalLength", "PetalWidth", "FlowerType"])

# %%
df
# Out:
#      SetosaLength  SetosaWidth  PetalLength  PetalWidth      FlowerType
# 0             5.1          3.5          1.4         0.2     Iris-setosa
# 1             4.9          3.0          1.4         0.2     Iris-setosa
# 2             4.7          3.2          1.3         0.2     Iris-setosa
# 3             4.6          3.1          1.5         0.2     Iris-setosa
# 4             5.0          3.6          1.4         0.2     Iris-setosa
# 5             5.4          3.9          1.7         0.4     Iris-setosa
# 6             4.6          3.4          1.4         0.3     Iris-setosa
# 7             5.0          3.4          1.5         0.2     Iris-setosa
# 8             4.4          2.9          1.4         0.2     Iris-setosa
# 9             4.9          3.1          1.5         0.1     Iris-setosa
# 10            5.4          3.7          1.5         0.2     Iris-setosa
# 11            4.8          3.4          1.6         0.2     Iris-setosa
# 12            4.8          3.0          1.4         0.1     Iris-setosa
# 13            4.3          3.0          1.1         0.1     Iris-setosa
# 14            5.8          4.0          1.2         0.2     Iris-setosa
# 15            5.7          4.4          1.5         0.4     Iris-setosa
# 16            5.4          3.9          1.3         0.4     Iris-setosa
# 17            5.1          3.5          1.4         0.3     Iris-setosa
# 18            5.7          3.8          1.7         0.3     Iris-setosa
# 19            5.1          3.8          1.5         0.3     Iris-setosa
# 20            5.4          3.4          1.7         0.2     Iris-setosa
# 21            5.1          3.7          1.5         0.4     Iris-setosa
# 22            4.6          3.6          1.0         0.2     Iris-setosa
# 23            5.1          3.3          1.7         0.5     Iris-setosa
# 24            4.8          3.4          1.9         0.2     Iris-setosa
# 25            5.0          3.0          1.6         0.2     Iris-setosa
# 26            5.0          3.4          1.6         0.4     Iris-setosa
# 27            5.2          3.5          1.5         0.2     Iris-setosa
# 28            5.2          3.4          1.4         0.2     Iris-setosa
# 29            4.7          3.2          1.6         0.2     Iris-setosa
# ..            ...          ...          ...         ...             ...
# 120           6.9          3.2          5.7         2.3  Iris-virginica
# 121           5.6          2.8          4.9         2.0  Iris-virginica
# 122           7.7          2.8          6.7         2.0  Iris-virginica
# 123           6.3          2.7          4.9         1.8  Iris-virginica
# 124           6.7          3.3          5.7         2.1  Iris-virginica
# 125           7.2          3.2          6.0         1.8  Iris-virginica
# 126           6.2          2.8          4.8         1.8  Iris-virginica
# 127           6.1          3.0          4.9         1.8  Iris-virginica
# 128           6.4          2.8          5.6         2.1  Iris-virginica
# 129           7.2          3.0          5.8         1.6  Iris-virginica
# 130           7.4          2.8          6.1         1.9  Iris-virginica
# 131           7.9          3.8          6.4         2.0  Iris-virginica
# 132           6.4          2.8          5.6         2.2  Iris-virginica
# 133           6.3          2.8          5.1         1.5  Iris-virginica
# 134           6.1          2.6          5.6         1.4  Iris-virginica
# 135           7.7          3.0          6.1         2.3  Iris-virginica
# 136           6.3          3.4          5.6         2.4  Iris-virginica
# 137           6.4          3.1          5.5         1.8  Iris-virginica
# 138           6.0          3.0          4.8         1.8  Iris-virginica
# 139           6.9          3.1          5.4         2.1  Iris-virginica
# 140           6.7          3.1          5.6         2.4  Iris-virginica
# 141           6.9          3.1          5.1         2.3  Iris-virginica
# 142           5.8          2.7          5.1         1.9  Iris-virginica
# 143           6.8          3.2          5.9         2.3  Iris-virginica
# 144           6.7          3.3          5.7         2.5  Iris-virginica
# 145           6.7          3.0          5.2         2.3  Iris-virginica
# 146           6.3          2.5          5.0         1.9  Iris-virginica
# 147           6.5          3.0          5.2         2.0  Iris-virginica
# 148           6.2          3.4          5.4         2.3  Iris-virginica
# 149           5.9          3.0          5.1         1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
df.groupby("FlowerType").PetalWidth.hist()
# Out:
# FlowerType
# Iris-setosa        Axes(0.125,0.125;0.775x0.755)
# Iris-versicolor    Axes(0.125,0.125;0.775x0.755)
# Iris-virginica     Axes(0.125,0.125;0.775x0.755)
# Name: PetalWidth, dtype: object

# %%
def loadDataset (filename, split=0.75):
    import csv, random
    trainSet=[]
    testSet=[]
    with open (filename, 'r') as csv_file:
        flowers = csv.reader(csv_file)
        dataset = list (flowers)
        for i in range (len(dataset)-1):
            if random.random() < split:
                trainSet.append(dataset[i])
            else:
                testSet.append(dataset[i])
        return trainSet, testSet
trainSet, testSet = loadDataset('iris.data.txt')

# %%
def euclidianDistance (inst1, inst2, length):
    import math
    # sqrt(sum((x1 - y1)^2 + ... + (xn - yn)^2))
    distance = 0
    for i in range(length):
        distance += pow(inst1[i] - inst2[i], 2)
    return math.sqrt (distance)

a = [1,2,4,5,'a']
b = [2,2,6,7,'b']
euclidianDistance (a,b,4)
# Out:
# 3.0

# %%
def getNeighbours (trainSet, testInstance, k):
    import operator
    distances = []
    itemLen = len(testInstance)-1
    print (itemLen)
    for i in range (len(trainSet)):
        dist = euclidianDistance (trainSet[i], testInstance, itemLen)
        distances.append ((trainSet[i], dist))
    distances.sort (key=operator.itemgetter(1))
    neighbours = []
    
    for i in range (k):
        neighbours.append (distances[i][0])
    return neighbours
a = [[1,2,4,5,'a'], [3,4,5,4,'b']]
b = [2,2,6,7]
getNeighbours(a,b,1)
# Out:
# 3
# [2, 2, 6, 7] [1, 2, 4, 5, 'a']
# [2, 2, 6, 7] [3, 4, 5, 4, 'b']
# [[1, 2, 4, 5, 'a']]

# %%
def getResponse (neighbours):
    import operator
    classVotes = {}
    for i in range(len(neighbours)):
        response = neighbours[i][-1]
        if response in classVotes:
            classVotes[response] += 1
        else:
            classVotes[response] = 1
    sortedVotes = sorted (classVotes.items(), key=operator.itemgetter(1), reverse=True)
    return sortedVotes[0][0]

neighbors = [[1,1,1,'a'], [2,2,2,'a'], [3,3,3,'b']]
response = getResponse(neighbors)
print(response)
# Out:
# a

# %%
def getAccuracy (testSet, predictions):
    correct = 0
    for i in range (len(testSet)):
        if testSet[i][-1] == predictions[i]:
            correct += 1
            
    return (correct / len(testSet)) * 100
# Out:
# 60.0

# %%
trainSet, testSet = loadDataset('iris.data.txt')
k = 3
for i in range (len(testSet)):
    neighbours = getNeighbours(trainSet, testSet[i], k)
    prediction = getResponse (neighbours)
    predictions.append (predicition)
# Out:
# 4
# ['5.1', '3.5', '1.4', '0.2', 'Iris-setosa'] ['4.7', '3.2', '1.3', '0.2', 'Iris-setosa']
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-70-2626c397d8af> in <module>()
#       2 k = 3
#       3 for i in range (len(testSet)):
# ----> 4     neighbours = getNeighbours(trainSet, testSet[i], k)
#       5     prediction = getResponse (neighbours)
#       6     predictions.append (predicition)
#
# <ipython-input-69-ccc5840ff4e1> in getNeighbours(trainSet, testInstance, k)
#       6     for i in range (len(trainSet)):
#       7         print (testInstance, trainSet[i])
# ----> 8         dist = euclidianDistance (trainSet[i], testInstance, itemLen)
#       9         distances.append ((trainSet[i], dist))
#      10     distances.sort (key=operator.itemgetter(1))
#
# <ipython-input-51-69ceb3ab80c6> in euclidianDistance(inst1, inst2, length)
#       4     distance = 0
#       5     for i in range(length):
# ----> 6         distance += pow(inst1[i] - inst2[i], 2)
#       7     return math.sqrt (distance)
#       8
#
# TypeError: unsupported operand type(s) for -: 'str' and 'str'
